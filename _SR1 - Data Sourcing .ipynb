# %%
import pandas as pd

# Load the dataset
file_path =( r"C:\Users\pac computers\OneDrive - Mangosuthu University of Technology\Desktop\TP2 Test2\InformalDataset.csv.csv")
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head()
# Out:
#                  Settlement Name      Location      Province  \
# 0                    Khayelitsha     Cape Town  Western Cape
# 1                      Diepsloot  Johannesburg       Gauteng
# 2                      Alexandra  Johannesburg       Gauteng
# 3                 Joe Slovo Park     Cape Town  Western Cape
# 4  Barberton Informal Settlement     Barberton    Mpumalanga
#
#   Date of Establishment Initial Population Current Population Sanitation  \
# 0                  1983                100             391749         No
# 1                  1995                100             138329         No
# 2                  1912                100             179624    Partial
# 3                  1990                100            Unknown         No
# 4                  2000                100            Unknown         No
#
#   Water Supply Electricity                    Health Issues  \
# 0      Partial          No                 High crime rates
# ...

# %% [markdown]
# # Informal Settlements Analysis
#
#
# ### Dataset Selection
# I have chosen a dataset titled "Informal Settlements" which includes information on various informal settlements across different regions. The dataset was provided in CSV format.
#
# ### Justification of Suitability
# **Credibility of the Source**:
# The dataset appears to have been compiled with a detailed account of various informal settlements, providing data on key aspects such as population, sanitation, and government interventions.
#
# **Data Completeness**:
# The dataset includes multiple columns that cover important variables necessary for analyzing informal settlements. This comprehensiveness ensures a robust analysis.
#
# **Relevance**:
#
# The dataset contains several columns that are directly relevant to the study of informal settlements. Two key columns that illustrate this relevance are:
#
# **Sanitation**:
# This column provides data on the availability and quality of sanitation facilities in informal settlements, which is crucial for understanding living conditions and public health challenges.
#
# **Government Interventions**:
#
# This column includes information on the types of interventions carried out by the government in these areas, which is important for assessing efforts to improve conditions in informal settlements.
#
# By leveraging these columns, we can perform a detailed analysis of the living conditions in informal settlements and the effectiveness of interventions aimed at improving these conditions, which aligns well with the theme of our study.
#
# ### Columns Selected for Analysis
# **Sanitation**:
# This column provides data that is essential for understanding the availability and quality of sanitation facilities within informal settlements.
# **Government Interventions**:
# This column allows us to assess the types of interventions being implemented to address issues within these settlements and evaluate their effectiveness.
#
# ### Conclusion
# The "Informal Settlements" dataset is a suitable and credible source for analyzing informal settlements. Its comprehensive nature and the relevance of specific columns make it an excellent choice for this study.
